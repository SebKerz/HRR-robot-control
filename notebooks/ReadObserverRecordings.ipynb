# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import numpy as np
sns.set_theme('notebook')

# %%
data_path = pathlib.Path("~").expanduser() / "Documents" / "robot_recordings"

# %%
data = np.load(data_path / "unscrew_v2_data_008.npy", allow_pickle=True).item()

# %%
data
# Out:
# {'q': array([[-0.79537183,  0.08900799, -2.27789283,  2.18215966,  1.05775082,
#          -1.65804327],
#         [-0.79537183,  0.08900799, -2.27789283,  2.18215966,  1.05775082,
#          -1.65804327],
#         [-0.79534221,  0.0893513 , -2.27812338,  2.18245244,  1.05806339,
#          -1.65859628],
#         ...,
#         [-0.7914325 ,  0.13713227, -2.30606699,  2.21895218,  1.10056818,
#          -1.72975552],
#         [-0.78789866,  0.13659087, -2.3072691 ,  2.22262716,  1.09915996,
#          -1.73188818],
#         [-0.78792125,  0.13626918, -2.30727434,  2.22247696,  1.09897947,
#          -1.73159587]]),
#  'B_F_msr': array([[ 1.01922837e-01, -2.28543190e-03, -6.51214275e-04,
#          -3.18524765e-02,  1.63948906e-02, -2.75397809e-02],
#         [ 1.22778044e-01,  4.35766222e-02, -8.34121662e-02,
#          -7.00325366e-02,  8.20039135e-02, -4.02921083e-02],
#         [-5.18576331e-03,  5.53688573e-02,  1.45617113e-01,
# ...

# %%
plt.plot(data['B_err_F'][:, :3])
